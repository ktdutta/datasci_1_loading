# %%
import pandas as pd

# %% [markdown]
# ## First CSV File Example
#
# #### This set of data is about the different types of diabetes indicators seen in patients in the state of New York. This data is being used to determine what is the most common indicator within the average population.

# %%
df = pd.read_csv('diabetes-indicators.csv')
df[:10]
# Out:
#              County Name  County Code            Region Name Indicator Number  \
# 0       Western New York          101       Western New York               d1
# 1           Finger Lakes          102           Finger Lakes               d1
# 2          New York City          107          New York City               d1
# 3       Central New York          103       Central New York               d1
# 4          New York-Penn          104          New York-Penn               d1
# 5  Northeastern New York          105  Northeastern New York               d1
# 6          Hudson Valley          106          Hudson Valley               d1
# 7         Nassau-Suffolk          108         Nassau-Suffolk               d1
# 8         New York State          999         New York State               d1
# 9       Western New York          101       Western New York              d1a
#
#                                            Indicator  Total Event Counts  \
# ...

# %% [markdown]
# ## Second CSV File Example
#
# #### This dataset is of the number of weightloss surgeries conducted in the state of California. The number of weight lot surgery cases are organized by the hospital and year they were performed in.

# %%
df2= pd.read_csv('weight-loss-surgeries.csv')
df2[:10]
# Out:
#    Year       County                                Hospital      OSHPDID  \
# 0  2006       Placer            Sutter Auburn Faith Hospital  106310791.0
# 1  2009       Orange                  Chapman Medical Center  106301140.0
# 2  2011       Placer         Sutter Roseville Medical Center  106311000.0
# 3  2012  Los Angeles                 Marina Del Rey Hospital  106190500.0
# 4  2012    San Mateo                        Sequoia Hospital  106410891.0
# 5  2013  Los Angeles                 Marina Del Rey Hospital  106190500.0
# 6  2013  Los Angeles                  Olympia Medical Center  106190534.0
# 7  2014  Los Angeles            Huntington Memorial Hospital  106190400.0
# 8  2005    Riverside  Southwest Healthcare System – Murrieta  106334068.0
# 9  2008    San Diego                       Alvarado Hospital  106370652.0
#
#     Surgery  # of Cases              Location 1
# 0   LAPRYGB        37.0   (38.94452, -121.0982)
# 1       VSG         6.0  (33.78785, -117.82586)
# ...

# %% [markdown]
# ## Third CSV File Example
#
# #### This dataset contains information regarding symptoms of depressive and anxiety disorders experienced in different types of subgroups. The subgroups were organized by age groups, education background, and location.

# %%
df3 = pd.read_csv('anxiety-depression-symptoms.csv')
df3[:10]
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
# 5  Symptoms of Depressive Disorder             By Age  United States
# 6  Symptoms of Depressive Disorder             By Age  United States
# 7  Symptoms of Depressive Disorder             By Age  United States
# 8  Symptoms of Depressive Disorder             By Sex  United States
# 9  Symptoms of Depressive Disorder             By Sex  United States
#
#              Subgroup Phase  Time Period     Time Period Label  \
# 0       United States     1            1  Apr 23 - May 5, 2020
# 1       18 - 29 years     1            1  Apr 23 - May 5, 2020
# ...

# %%
import json
import pandas as dp

# %% [markdown]
# ## First JSON File Example
#
# This data in this dataset reflects the number of people who have reached space relected by NASA. The important features in this dataset include the name of the individuals who made it to space and the statement of the trip being sucessful. Due to this data being public knowledge, the names of the  do not need to be deidentifed.

# %%
import json

# Writing data to a JSON file
data=dp.read_json('http://api.open-notify.org/astros.json')
data[:10]
# Out:
#    number                                          people  message
# 0      10    {'craft': 'ISS', 'name': 'Sergey Prokopyev'}  success
# 1      10      {'craft': 'ISS', 'name': 'Dmitry Petelin'}  success
# 2      10         {'craft': 'ISS', 'name': 'Frank Rubio'}  success
# 3      10   {'craft': 'Tiangong', 'name': 'Jing Haiping'}  success
# 4      10    {'craft': 'Tiangong', 'name': 'Gui Haichow'}  success
# 5      10    {'craft': 'Tiangong', 'name': 'Zhu Yangzhu'}  success
# 6      10     {'craft': 'ISS', 'name': 'Jasmin Moghbeli'}  success
# 7      10    {'craft': 'ISS', 'name': 'Andreas Mogensen'}  success
# 8      10    {'craft': 'ISS', 'name': 'Satoshi Furukawa'}  success
# 9      10  {'craft': 'ISS', 'name': 'Konstantin Borisov'}  success

# %% [markdown]
# ## Second JSON File Example
#
# In this dataset the main features are the values of the product codes for each individual food being listed. This helps determine what the additional food facts listed are pertaining too.

# %%
data1=dp.read_json('https://world.openfoodfacts.org/api/v0/product/5060292302201.json')
data1[:10]
# Out:
#                                        code  \
# _id                           5060292302201
# _keywords                     5060292302201
# added_countries_tags          5060292302201
# additives_debug_tags          5060292302201
# additives_n                   5060292302201
# additives_old_n               5060292302201
# additives_old_tags            5060292302201
# additives_original_tags       5060292302201
# additives_prev_original_tags  5060292302201
# additives_tags                5060292302201
#
#                                                                         product  \
# _id                                                               5060292302201
# _keywords                     [and, anything, appetizer, artificial, barbequ...
# added_countries_tags                                                         []
# additives_debug_tags                                                         []
# ...

# %% [markdown]
# ## Third JSON File Example
#
# This dataset contains information on the reported monthly delays of flights. The important features of this dataset is the hospital/state the delay occured at, the month of occurance, and the number of delays reported during the noted amountof time.

# %%
data2=dp.read_json('https://think.cs.vt.edu/corgis/datasets/json/airlines/airlines.json')
data2[:10]
# Out:
#                                              Airport  \
# 0  {'Code': 'ATL', 'Name': 'Atlanta, GA: Hartsfie...
# 1  {'Code': 'BOS', 'Name': 'Boston, MA: Logan Int...
# 2  {'Code': 'BWI', 'Name': 'Baltimore, MD: Baltim...
# 3  {'Code': 'CLT', 'Name': 'Charlotte, NC: Charlo...
# 4  {'Code': 'DCA', 'Name': 'Washington, DC: Ronal...
# 5  {'Code': 'DEN', 'Name': 'Denver, CO: Denver In...
# 6  {'Code': 'DFW', 'Name': 'Dallas/Fort Worth, TX...
# 7  {'Code': 'DTW', 'Name': 'Detroit, MI: Detroit ...
# 8  {'Code': 'EWR', 'Name': 'Newark, NJ: Newark Li...
# 9  {'Code': 'FLL', 'Name': 'Fort Lauderdale, FL: ...
#
#                                                 Time  \
# 0  {'Label': '2003/06', 'Month': 6, 'Month Name':...
# 1  {'Label': '2003/06', 'Month': 6, 'Month Name':...
# 2  {'Label': '2003/06', 'Month': 6, 'Month Name':...
# 3  {'Label': '2003/06', 'Month': 6, 'Month Name':...
# 4  {'Label': '2003/06', 'Month': 6, 'Month Name':...
# 5  {'Label': '2003/06', 'Month': 6, 'Month Name':...
# ...

# %%
import pandas as pp

# %% [markdown]
# ## First Excel File Example
#
# This type of dataset is a dictionary for the terms and values which are used in the numerical dataset for MRSA blood infections reported to the CDC by hospitals in California. The dataset states a feature, how the feature is measured, and the definition of each feature in the data collected.

# %%
dataset1=pp.read_excel('mrsa-rehabilation.xlsx')
dataset1[:10]
# Out:
#                   Field      Format  \
# 0                  Year      Number
# 1                 State  Plain Text
# 2                   HAI  Plain Text
# 3          Facility_ID1  Plain Text
# 4        Facility_Name1  Plain Text
# 5                County  Plain Text
# 6  Hospital_Onset_Cases      Number
# 7          Patient_Days      Number
# 8   Hospital_Onset_Rate      Number
# 9     CI_95_Lower_Limit      Number
#
#                                           Definition
# 0                       Year MRSA infection reported
# 1                                         California
# 2  Healthcare-associated infection (HAI): Methici...
# 3  Facility ID. The primary key used to track fac...
# 4  Facility name for California free-standing reh...
# 5  The name of the California county where the fa...
# 6  Count of hospital onset (HO) MRSA BSIs based o...
# 7  A count of the number of patients in the hospi...
# 8  The incidence density rate of HO MRSA BSIs, ca...
# ...

# %% [markdown]
# ## Second Excel File Example
#
# This dataset is an index for modified retail food environment index. The important features/columns of this dataset are the HCI indicators. The HCI indicators are a method of measurement used to asssess quality. The quality of different food environments in the state of California are being measured.

# %%
dataset2=pp.read_excel('modified-retail-food-environment-index.xlsx')
dataset2[:10]
# Out:
#    ind_id                          ind_definition  reportyear  race_eth_code  \
# 0      75  Modified retail food environment index        2017              9
# 1      75  Modified retail food environment index        2017              9
# 2      75  Modified retail food environment index        2017              9
# 3      75  Modified retail food environment index        2017              9
# 4      75  Modified retail food environment index        2017              9
# 5      75  Modified retail food environment index        2017              9
# 6      75  Modified retail food environment index        2017              9
# 7      75  Modified retail food environment index        2017              9
# 8      75  Modified retail food environment index        2017              9
# 9      75  Modified retail food environment index        2017              9
#
#   race_eth_name geotype  geotypevalue       geoname   county_name  \
# ...

# %% [markdown]
# ## Third Excel File Example
#
# This dataset contains growth in objectives set by the California Wellness Plan which aims to help bring health care to low-income areas. The data features in the  columns are stating the improvements made over the years to work towards each of their four goals.

# %%
dataset3=pp.read_excel('wellness-plan.xlsx')
dataset3[:10]
# Out:
#               Objective Number  \
# 0  GOAL 1: Healthy Communities
# 1       Increase Health Status
# 2                       1.1.1S
# 3                       1.1.1I
# 4                       1.1.2I
# 5                       1.1.3I
# 6                       1.1.4I
# 7                       1.1.5I
# 8                       1.1.6I
# 9                       1.1.7I
#
#                                            Objective Developmental Objective  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2  By 2015, adopt health equity as a key consider...                     NaN
# 3  By 2018, increase the percentage of teens who ...                     NaN
# 4  By 2018, increase the percentage of people who...                       X
# 5  By 2018, increase the percentage of people who...                     NaN
# ...
